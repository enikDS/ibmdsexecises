# %% [markdown]
# <h1>Create and Share Your Jupyter Notebook<h1>

# %% [markdown]
# __Name: Enrico__ \
# Desired Occupation: Data Scientist

# %% [markdown]
# *I am interested in Data Science since it involves Statstics and Artificial Intelligence/Machine Learning*

# %% [markdown]
# <h3>Calculates 1 + 1 <h3>

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# [Coursera](https://www.coursera.org/)
# * Item 1
# * Item 2
# * Item 3
# ---
# ---
# ***
